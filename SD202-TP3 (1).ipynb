# %% [markdown]
# # SD202 TP3 - Views, Updates and Database Design
#
# The objectives for this TP are:
#
# 1. Create and use SQL Views
# 2. Update database content
# 3. Design the database schema for a Social Network
#
#
# For the first 2 parts we will use the _wine_ database and the Tables created in TP2.
#
# A reminder of the wine database schema:

# %% [raw]
# +-----------------------------------------+
# |                 Master1                 |
# +-----------------------------------------+
# | NV:      Wine number                    |
# | CRU:     Vineyard or group of vineyards |
# | DEGRE:   Alcohol content                |
# | MILL:    Vintage year                   |
# | QTE:     Number of bottles harvested    |
# | NP:      Producer number                |
# | NOM:     Producer's last name           |
# | PRENOM:  Producer's first name          |
# | REGION:  Wine growing region            |
# +-----------------------------------------+
#
# +-------------------------------------------------------------------+
# |                              Master2                              |
# +-------------------------------------------------------------------+
# | NV:      Wine number                                              |
# | CRU:     Vineyard or group of vineyards                           |
# | DEGRE:   Alcohol content                                          |
# | MILL:    Vintage year                                             |
# | DATES:   Buying date                                              |
# | LIEU:    Place where the wine was sold                            |
# | QTE:     Number of bottles bought                                 |
# | NB:      Client (buveur) number                                   |
# | NON:     Client's last name                                       |
# | PRENOM:  Client's first name                                      |
# | TYPE:    Type of client by volume of purchases                    |
# | REGION:  Administrative Region (different to wine growing region) |
# +-------------------------------------------------------------------+

# %%
import sqlite3

# %%
def printSchema(connection):
    ### Source: http://stackoverflow.com/a/35092773/4765776
    for (tableName,) in connection.execute(
        """
        select NAME from SQLITE_MASTER where TYPE='table' order by NAME;
        """
    ):
        print("{}:".format(tableName))
        for (
            columnID, columnName, columnType,
            columnNotNull, columnDefault, columnPK,
        ) in connection.execute("pragma table_info('{}');".format(tableName)):
            print("  {id}: {name}({type}){null}{default}{pk}".format(
                id=columnID,
                name=columnName,
                type=columnType,
                null=" not null" if columnNotNull else "",
                default=" [{}]".format(columnDefault) if columnDefault else "",
                pk=" *{}".format(columnPK) if columnPK else "",
            ))

# %%
conn = sqlite3.connect('wine.db')
c = conn.cursor()
print("Database schema:")
printSchema(conn)
# Out:
# Database schema:
# MASTER1:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)
#   4: QTE(NUM)
#   5: NP(NUM)
#   6: NOM(TEXT)
#   7: PRENOM(TEXT)
#   8: REGION(TEXT)
# MASTER2:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: DEGRE(NUM)
#   3: MILL(NUM)
#   4: DATES(NUM)
#   5: LIEU(TEXT)
#   6: QTE(NUM)
#   7: NB(NUM)
#   8: NOM(TEXT)
#   9: PRENOM(TEXT)
#   10: TYPE(TEXT)
#   11: REGION(TEXT)
# RBA:
#   0: NB(NUM)
#   1: NOM(TEXT)
#   2: PRENOM(TEXT)
#   3: TYPE(TEXT)
# RBB:
#   0: NB(NUM)
#   1: NOM(TEXT)
#   2: PRENOM(TEXT)
#   3: TYPE(TEXT)
# achats:
#   0: NV(NUM)
#   1: NB(NUM)
#   2: QTE(NUM)
#   3: DATES(NUM)
#   4: LIEU(TEXT)
# buveurs:
#   0: NB(NUM)
#   1: NOM(TEXT)
#   2: PRENOM(TEXT)
#   3: TYPE(TEXT)
# locations:
#   0: LIEU(TEXT)
#   1: REGION(TEXT)
# vins:
#   0: NV(NUM)
#   1: CRU(TEXT)
#   2: MILL(NUM)
#   3: DEGRE(NUM)

# %% [markdown]
# Again, we recommend inline %sql as an alternative to the sqlite3 package

# %%
# %load_ext sql
# %sql sqlite:///wine.db
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# 'Connected: None@wine.db'

# %% [markdown]
# Recreate the Tables in 3NF/BCNF from Master2 as you did in the TP2

# %%
# %sql DROP TABLE IF EXISTS vins;
# %sql DROP TABLE IF EXISTS buveurs;
# %sql DROP TABLE IF EXISTS achats;
# %sql DROP TABLE IF EXISTS locations;

# %sql CREATE TABLE vins AS \
SELECT DISTINCT NV, CRU, MILL, DEGRE \
FROM MASTER2 \
WHERE NV is not NULL;

# %sql CREATE TABLE buveurs AS \
SELECT DISTINCT NB, NOM, PRENOM, TYPE \
FROM MASTER2 \
WHERE NB is not NULL;

# %sql CREATE TABLE achats AS \
SELECT DISTINCT NV, NB, QTE, DATES, LIEU \
FROM MASTER2 \
WHERE NB is not NULL and NV is not NULL;

# %sql CREATE TABLE locations AS \
SELECT DISTINCT LIEU, REGION \
FROM MASTER2 \
WHERE LIEU is not NULL;
# Out:
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# []

# %% [markdown]
# __
# # PART I: CREATE AND USE VIEWS
#
# A view is a virtual table based on the result-set of an SQL statement. Views are stored in the database with an associated name.
#
# Views are created following the syntax:
#
# ```sql
# CREATE VIEW view_name AS
# SELECT column1, column2.....
# FROM table_name
# WHERE [condition];
# ```
#
# An useful command is:
#
# ```sql
# DROP VIEW IF EXISTS view_name;
# ```
#
#
# __Note:__ Use it with caution (only drop something if you are sure)

# %% [markdown]
# __1.1__ Create a view 'bons_buveurs' with the clients (buveurs) of type 'gros' or 'moyen'.

# %%
# %sql DROP VIEW IF EXISTS bons_buveurs;
# %sql CREATE VIEW bons_buveurs AS \
SELECT DISTINCT b.NB, NOM, PRENOM, TYPE \
FROM buveurs b \
WHERE TYPE in ('gros', 'moyen');
# Out:
# 1 rows affected.
# 1 rows affected.
# []

# %%
# Test
# %sql SELECT * FROM bons_buveurs ORDER BY nb;
# Out:
# Done.
# [(2, 'Artaud', 'Antonin', 'moyen'),
#  (3, 'Aron', 'Raymond', 'gros'),
#  (4, 'Apollinaire', 'Guillaume', 'moyen'),
#  (6, 'Arrabal', 'Fernando', 'gros'),
#  (7, 'Anouilh', 'Jean', 'moyen'),
#  (8, 'Aragon', 'Louis', 'gros'),
#  (10, 'Andersen', 'Yann', 'gros'),
#  (12, 'Bataille', 'Georges', 'moyen'),
#  (13, 'Barthes', 'Roland', 'moyen'),
#  (14, 'Bory', 'Jean Louis', 'gros'),
#  (16, 'Balzac', 'Honore de', 'moyen'),
#  (18, 'Celine', 'Louis Ferdinand', 'gros'),
#  (19, 'Ciceron', None, 'gros'),
#  (20, 'Chateaubriand', 'Francois-Rene de', 'moyen'),
#  (22, 'Cocteau', 'Jean', 'gros'),
#  (24, 'Courrier', 'Paul Louis', 'moyen'),
#  (26, 'Diderot', 'Denis', 'moyen'),
#  (27, 'Dumas', 'Alexandre', 'gros'),
#  (28, 'Dostoievsky', 'Fiodor', 'gros'),
#  (31, 'Dante', None, 'gros'),
#  (32, 'Eluard', 'Paul', 'moyen'),
#  (33, 'Flaubert', 'Gustave', 'moyen'),
#  (35, 'Fromentin', 'Eugene', 'gros'),
#  (39, 'Montesquieu', None, 'gros'),
#  (42, 'Goethe', 'Johann Wolfgang von', 'moyen'),
#  (43, 'Musset', 'Alfred de', 'gros'),
#  (46, 'Hugo', 'Victor', 'moyen'),
#  (48, 'Hardy', 'Thomas', 'moyen'),
#  (50, 'Lautreamont', None, 'moyen'),
#  (53, 'Lamartine', 'Alphonse de', 'gros'),
#  (55, 'Michelet', 'Jules', 'gros'),
#  (57, 'Marx', 'Karl', 'gros'),
#  (58, 'Marivaux', 'Pierre Carlet de Chamblain de', 'gros'),
#  (60, 'Ovide', None, 'gros'),
#  (62, 'Proust', 'Marcel', 'moyen'),
#  (64, 'Platon', None, 'gros'),
#  (66, 'Perec', 'Georges', 'gros'),
#  (68, 'Prevert', 'Jacques', 'gros'),
#  (70, 'Paulhan', 'Jean', 'gros'),
#  (72, 'Rabelais', 'Francois', 'gros'),
#  (73, 'Poe', 'Allan Edgard', 'moyen'),
#  (75, 'Ronsard', 'Pierre', 'moyen'),
#  (76, 'Racine', 'Jean', 'gros'),
#  (78, 'Sandier', 'Jules', 'moyen'),
#  (79, 'Sade', 'Donatien Alphonse Fran¿¿s de', 'gros'),
#  (81, 'Sartre', 'Jean-Paul', 'gros'),
#  (83, 'Sophocle', None, 'gros'),
#  (84, 'Sue', 'Eugene', 'moyen'),
#  (86, 'Saint Exupery', 'Antoine de', 'gros'),
#  (87, 'Segur', 'Comtesse de', 'gros'),
#  (91, 'Verlaine', 'Paul', 'gros'),
#  (93, 'Virgile', None, 'gros'),
#  (94, 'Zola', 'Emile', 'moyen'),
#  (95, 'Zorn', 'Fritz', 'moyen'),
#  (98, 'Maturin', 'Robert', 'gros'),
#  (99, 'Cesar', 'Jules', 'gros')]

# %% [markdown]
# __1.2__ Create the view 'buveurs_asec' with clients (buveurs) who have not bought any wine.

# %%
# %sql DROP VIEW IF EXISTS buveurs_asec;
# %sql CREATE VIEW buveurs_asec AS \
SELECT b.NB, NOM, PRENOM, TYPE \
FROM buveurs b \
EXCEPT \
SELECT b.NB, NOM, PRENOM, TYPE \
FROM buveurs b, achats a \
WHERE b.NB = a.NB and QTE is not NULL;
# Out:
# 1 rows affected.
# 1 rows affected.
# []

# %%
# Test
# %sql SELECT * FROM buveurs_asec ORDER BY nb;
# Out:
# Done.
# [(11, 'Breton', 'Andre', 'petit'),
#  (13, 'Barthes', 'Roland', 'moyen'),
#  (16, 'Balzac', 'Honore de', 'moyen'),
#  (18, 'Celine', 'Louis Ferdinand', 'gros'),
#  (20, 'Chateaubriand', 'Francois-Rene de', 'moyen'),
#  (21, 'Corbiere', 'Tristan', 'petit'),
#  (23, 'Corneille', 'Pierre', 'petit'),
#  (25, 'Char', 'Rene', 'petit'),
#  (27, 'Dumas', 'Alexandre', 'gros'),
#  (29, 'Fournier', 'Alain', 'petit'),
#  (32, 'Eluard', 'Paul', 'moyen'),
#  (34, 'Mauriac', 'Francois', 'petit'),
#  (35, 'Fromentin', 'Eugene', 'gros'),
#  (36, 'Maurois', 'Andre', 'petit'),
#  (37, 'Freud', 'Sigmund', 'petit'),
#  (39, 'Montesquieu', None, 'gros'),
#  (42, 'Goethe', 'Johann Wolfgang von', 'moyen'),
#  (43, 'Musset', 'Alfred de', 'gros'),
#  (46, 'Hugo', 'Victor', 'moyen'),
#  (47, 'Gary', 'Romain', 'petit'),
#  (51, 'Lafargue', 'Paul', 'petit'),
#  (53, 'Lamartine', 'Alphonse de', 'gros'),
#  (54, 'Aurele', 'Marc', 'petit'),
#  (55, 'Michelet', 'Jules', 'gros'),
#  (56, 'Nerval', 'Gerard de', 'petit'),
#  (57, 'Marx', 'Karl', 'gros'),
#  (59, 'Nietzsche', 'Friedrich', 'petit'),
#  (63, 'Maupassant', 'Guy de', 'petit'),
#  (64, 'Platon', None, 'gros'),
#  (65, 'Pascal', 'Blaise', 'petit'),
#  (66, 'Perec', 'Georges', 'gros'),
#  (67, 'Nin', 'Anais', 'petit'),
#  (68, 'Prevert', 'Jacques', 'gros'),
#  (69, 'Queneau', 'Raymond', 'petit'),
#  (70, 'Paulhan', 'Jean', 'gros'),
#  (71, 'Radiguet', 'Raymond', 'petit'),
#  (72, 'Rabelais', 'Francois', 'gros'),
#  (73, 'Poe', 'Allan Edgard', 'moyen'),
#  (74, 'Rimbaud', 'Arthur', 'petit'),
#  (76, 'Racine', 'Jean', 'gros'),
#  (77, 'Rousseau', 'Jean-Jacques', 'petit'),
#  (78, 'Sandier', 'Jules', 'moyen'),
#  (79, 'Sade', 'Donatien Alphonse Fran¿¿s de', 'gros'),
#  (81, 'Sartre', 'Jean-Paul', 'gros'),
#  (83, 'Sophocle', None, 'gros'),
#  (84, 'Sue', 'Eugene', 'moyen'),
#  (85, 'Segalen', 'Victor', 'petit'),
#  (86, 'Saint Exupery', 'Antoine de', 'gros'),
#  (87, 'Segur', 'Comtesse de', 'gros'),
#  (88, 'Shakespeare', 'William', 'petit'),
#  (89, 'Stendhal', None, 'petit'),
#  (90, 'Vian', 'Boris', 'petit'),
#  (91, 'Verlaine', 'Paul', 'gros'),
#  (93, 'Virgile', None, 'gros'),
#  (95, 'Zorn', 'Fritz', 'moyen'),
#  (98, 'Maturin', 'Robert', 'gros'),
#  (99, 'Cesar', 'Jules', 'gros')]

# %% [markdown]
# __1.3__ Create the view 'buveurs_achats' complementary to the previous one.

# %%
# %sql DROP VIEW IF EXISTS buveurs_achats;
# %sql CREATE VIEW buveurs_achats AS \
SELECT DISTINCT b.NB, NOM, PRENOM, TYPE \
FROM buveurs b, achats a \
WHERE a.NB = b.NB and QTE is not NULL;
# Out:
# 1 rows affected.
# 1 rows affected.
# []

# %%
# Test
# %sql SELECT * FROM buveurs_achats ORDER BY nb;
# Out:
# Done.
# [(1, 'Aristote', None, 'petit'),
#  (2, 'Artaud', 'Antonin', 'moyen'),
#  (3, 'Aron', 'Raymond', 'gros'),
#  (4, 'Apollinaire', 'Guillaume', 'moyen'),
#  (5, 'Audiberti', 'Jacques', 'petit'),
#  (6, 'Arrabal', 'Fernando', 'gros'),
#  (7, 'Anouilh', 'Jean', 'moyen'),
#  (8, 'Aragon', 'Louis', 'gros'),
#  (9, 'Ajar', 'Emile', 'petit'),
#  (10, 'Andersen', 'Yann', 'gros'),
#  (12, 'Bataille', 'Georges', 'moyen'),
#  (14, 'Bory', 'Jean Louis', 'gros'),
#  (15, 'Baudelaire', 'Charles', 'petit'),
#  (17, 'Camus', 'Albert', 'petit'),
#  (19, 'Ciceron', None, 'gros'),
#  (22, 'Cocteau', 'Jean', 'gros'),
#  (24, 'Courrier', 'Paul Louis', 'moyen'),
#  (26, 'Diderot', 'Denis', 'moyen'),
#  (28, 'Dostoievsky', 'Fiodor', 'gros'),
#  (30, 'La Fontaine', 'Jean de', 'petit'),
#  (31, 'Dante', None, 'gros'),
#  (33, 'Flaubert', 'Gustave', 'moyen'),
#  (38, 'Montaigne', 'Michel de', 'petit'),
#  (40, 'Moliere', None, 'petit'),
#  (41, 'Gauthier', 'Theophile', 'petit'),
#  (44, 'Gide', 'Andre', 'petit'),
#  (45, 'Giono', 'Jean', 'petit'),
#  (48, 'Hardy', 'Thomas', 'moyen'),
#  (49, 'Kafka', 'Franz', 'petit'),
#  (50, 'Lautreamont', None, 'moyen'),
#  (52, 'Carroll', 'Lewis', 'petit'),
#  (58, 'Marivaux', 'Pierre Carlet de Chamblain de', 'gros'),
#  (60, 'Ovide', None, 'gros'),
#  (61, 'Mallarme', 'Stephane', 'petit'),
#  (62, 'Proust', 'Marcel', 'moyen'),
#  (75, 'Ronsard', 'Pierre', 'moyen'),
#  (80, 'Sand', 'Georges', 'petit'),
#  (82, 'Roussel', 'Rene', 'petit'),
#  (92, 'Verne', 'Jules', 'petit'),
#  (94, 'Zola', 'Emile', 'moyen'),
#  (96, 'Wilde', 'Oscar', 'petit'),
#  (97, 'Vigny', 'Alfred de', 'petit'),
#  (100, 'Woolf', 'Virginia', 'petit')]

# %% [markdown]
# __1.4__ Create the view 'q83pl' (LIEU, CRU, QTE_BUE) that provides by LIEU and CRU the total quantities bought in 1983 by all the clients (buveurs).

# %%
# %sql DROP VIEW IF EXISTS q83pl;
# %sql CREATE VIEW q83pl AS \
SELECT a.LIEU, v.CRU, SUM(a.QTE) as QTE_BUE \
FROM achats a, vins v \
WHERE a.DATES LIKE '%1983%' and a.NV = v.NV \
GROUP BY v.CRU \
ORDER BY a.LIEU, v.CRU;
# Out:
# 1 rows affected.
# 1 rows affected.
# []

# %%
# Test
# %sql SELECT * FROM q83pl;
# Out:
# Done.
# [('CAEN', 'Seyssel', 3),
#  ('LILLE', 'Pommard', 5),
#  ('LYON', 'Julienas', 2),
#  ('PARIS', 'Beaujolais Primeur', 4),
#  ('PARIS', 'Coteaux du Tricastin', 1),
#  ('PARIS', 'Pouilly Vinzelles', 3),
#  ('RENNES', 'Mercurey', 1),
#  ('ROCQUENCOURT', 'Beaujolais Villages', 270),
#  ('ROCQUENCOURT', 'Saint Amour', 80)]

# %% [markdown]
# __1.5__ Can we define the same view with ascending order over the attribute QTE? Provide an explanation for your answer.

# %% [raw]
# Answer:

# %% [markdown]
# ___
# # PART II: UPDATE DATABASE CONTENT
#
# The syntax for the Update statement is:
#
# ```sql
# UPDATE table_name
# SET column1 = value1, column2 = value2...., columnN = valueN
# WHERE [condition];
# ```
#
# The syntax for the Insert statement is:
#
# ```sql
# INSERT INTO TABLE_NAME [(column1, column2, column3,...columnN)]
# VALUES (value1, value2, value3,...valueN);
# ```
#
#
# Database updates are commited automatically in Jupyter/Python. _Transactions_ are an option to control and reverse changes. Additionally we can just reload a backup of the database (NOT an option in deployed systems)
#
# __Note:__ Different to other Database Management Systems, SQLite views are read-only and so you may not execute a DELETE, INSERT or UPDATE statement on a view.

# %% [markdown]
# __2.1__ Create a table 'RBB' with the same schema as 'bons_buveurs' which contains the tuples selected from 'bons_buveurs'

# %%
# %sql DROP TABLE IF EXISTS RBB;
# %sql CREATE TABLE RBB AS \
SELECT * FROM bons_buveurs;
# Out:
# Done.
# 1 rows affected.
# []

# %%
# Test
# %sql SELECT * FROM RBB;
# Out:
# Done.
# [(13, 'Barthes', 'Roland', 'moyen'),
#  (16, 'Balzac', 'Honore de', 'moyen'),
#  (18, 'Celine', 'Louis Ferdinand', 'gros'),
#  (20, 'Chateaubriand', 'Francois-Rene de', 'moyen'),
#  (27, 'Dumas', 'Alexandre', 'gros'),
#  (32, 'Eluard', 'Paul', 'moyen'),
#  (35, 'Fromentin', 'Eugene', 'gros'),
#  (39, 'Montesquieu', None, 'gros'),
#  (42, 'Goethe', 'Johann Wolfgang von', 'moyen'),
#  (43, 'Musset', 'Alfred de', 'gros'),
#  (46, 'Hugo', 'Victor', 'moyen'),
#  (53, 'Lamartine', 'Alphonse de', 'gros'),
#  (55, 'Michelet', 'Jules', 'gros'),
#  (57, 'Marx', 'Karl', 'gros'),
#  (64, 'Platon', None, 'gros'),
#  (66, 'Perec', 'Georges', 'gros'),
#  (68, 'Prevert', 'Jacques', 'gros'),
#  (70, 'Paulhan', 'Jean', 'gros'),
#  (72, 'Rabelais', 'Francois', 'gros'),
#  (73, 'Poe', 'Allan Edgard', 'moyen'),
#  (76, 'Racine', 'Jean', 'gros'),
#  (78, 'Sandier', 'Jules', 'moyen'),
#  (79, 'Sade', 'Donatien Alphonse Fran¿¿s de', 'gros'),
#  (81, 'Sartre', 'Jean-Paul', 'gros'),
#  (83, 'Sophocle', None, 'gros'),
#  (84, 'Sue', 'Eugene', 'moyen'),
#  (86, 'Saint Exupery', 'Antoine de', 'gros'),
#  (87, 'Segur', 'Comtesse de', 'gros'),
#  (91, 'Verlaine', 'Paul', 'gros'),
#  (93, 'Virgile', None, 'gros'),
#  (95, 'Zorn', 'Fritz', 'moyen'),
#  (98, 'Maturin', 'Robert', 'gros'),
#  (99, 'Cesar', 'Jules', 'gros'),
#  (2, 'Artaud', 'Antonin', 'moyen'),
#  (48, 'Hardy', 'Thomas', 'moyen'),
#  (7, 'Anouilh', 'Jean', 'moyen'),
#  (8, 'Aragon', 'Louis', 'gros'),
#  (50, 'Lautreamont', None, 'moyen'),
#  (3, 'Aron', 'Raymond', 'gros'),
#  (4, 'Apollinaire', 'Guillaume', 'moyen'),
#  (58, 'Marivaux', 'Pierre Carlet de Chamblain de', 'gros'),
#  (60, 'Ovide', None, 'gros'),
#  (10, 'Andersen', 'Yann', 'gros'),
#  (6, 'Arrabal', 'Fernando', 'gros'),
#  (62, 'Proust', 'Marcel', 'moyen'),
#  (75, 'Ronsard', 'Pierre', 'moyen'),
#  (26, 'Diderot', 'Denis', 'moyen'),
#  (28, 'Dostoievsky', 'Fiodor', 'gros'),
#  (22, 'Cocteau', 'Jean', 'gros'),
#  (24, 'Courrier', 'Paul Louis', 'moyen'),
#  (12, 'Bataille', 'Georges', 'moyen'),
#  (14, 'Bory', 'Jean Louis', 'gros'),
#  (19, 'Ciceron', None, 'gros'),
#  (33, 'Flaubert', 'Gustave', 'moyen'),
#  (31, 'Dante', None, 'gros'),
#  (94, 'Zola', 'Emile', 'moyen')]

# %% [markdown]
# __2.2__ Update the table you used to create 'bons_buveurs': Change the 'type' to 'gros' if the total of quantities bought is over 100.

# %% [markdown]
# Find the instances to update (schema may be different from the one in your table)

# %%
# %sql SELECT b.NB, NOM, PRENOM, TYPE, SUM(a.QTE) as TOTAL \
FROM buveurs b, achats a \
WHERE b.NB = a.NB and TYPE <> 'gros' and a.QTE is not NULL \
GROUP BY b.NB \
HAVING TOTAL > 100 ;
# Out:
# Done.
# [(2, 'Artaud', 'Antonin', 'moyen', 583),
#  (5, 'Audiberti', 'Jacques', 'petit', 113),
#  (9, 'Ajar', 'Emile', 'petit', 140),
#  (44, 'Gide', 'Andre', 'petit', 171)]

# %% [markdown]
# Update instances

# %%
# %sql UPDATE buveurs \
SET TYPE = 'gros' \
WHERE NB in (2,5,9,44);
# Out:
# 4 rows affected.
# []

# %% [markdown]
# __2.3__ Compare the content of _table_ 'RBB' and the _view_ 'bons_buveurs' after the update. What differences do you see? Explain

# %% [raw]
# The view have been modified by the update but not the table. That is explained by the fact that the table was created once from the tables that were modified but is not dependent from them, whereas the view is only a construct that shows us a particular portion of the tables that were modified, hence showing the updates.

# %%
# %sql SELECT * FROM bons_buveurs ORDER BY NB;
# Out:
# Done.
# [(2, 'Artaud', 'Antonin', 'gros'),
#  (3, 'Aron', 'Raymond', 'gros'),
#  (4, 'Apollinaire', 'Guillaume', 'moyen'),
#  (5, 'Audiberti', 'Jacques', 'gros'),
#  (6, 'Arrabal', 'Fernando', 'gros'),
#  (7, 'Anouilh', 'Jean', 'moyen'),
#  (8, 'Aragon', 'Louis', 'gros'),
#  (9, 'Ajar', 'Emile', 'gros'),
#  (10, 'Andersen', 'Yann', 'gros'),
#  (12, 'Bataille', 'Georges', 'moyen'),
#  (13, 'Barthes', 'Roland', 'moyen'),
#  (14, 'Bory', 'Jean Louis', 'gros'),
#  (16, 'Balzac', 'Honore de', 'moyen'),
#  (18, 'Celine', 'Louis Ferdinand', 'gros'),
#  (19, 'Ciceron', None, 'gros'),
#  (20, 'Chateaubriand', 'Francois-Rene de', 'moyen'),
#  (22, 'Cocteau', 'Jean', 'gros'),
#  (24, 'Courrier', 'Paul Louis', 'moyen'),
#  (26, 'Diderot', 'Denis', 'moyen'),
#  (27, 'Dumas', 'Alexandre', 'gros'),
#  (28, 'Dostoievsky', 'Fiodor', 'gros'),
#  (31, 'Dante', None, 'gros'),
#  (32, 'Eluard', 'Paul', 'moyen'),
#  (33, 'Flaubert', 'Gustave', 'moyen'),
#  (35, 'Fromentin', 'Eugene', 'gros'),
#  (39, 'Montesquieu', None, 'gros'),
#  (42, 'Goethe', 'Johann Wolfgang von', 'moyen'),
#  (43, 'Musset', 'Alfred de', 'gros'),
#  (44, 'Gide', 'Andre', 'gros'),
#  (46, 'Hugo', 'Victor', 'moyen'),
#  (48, 'Hardy', 'Thomas', 'moyen'),
#  (50, 'Lautreamont', None, 'moyen'),
#  (53, 'Lamartine', 'Alphonse de', 'gros'),
#  (55, 'Michelet', 'Jules', 'gros'),
#  (57, 'Marx', 'Karl', 'gros'),
#  (58, 'Marivaux', 'Pierre Carlet de Chamblain de', 'gros'),
#  (60, 'Ovide', None, 'gros'),
#  (62, 'Proust', 'Marcel', 'moyen'),
#  (64, 'Platon', None, 'gros'),
#  (66, 'Perec', 'Georges', 'gros'),
#  (68, 'Prevert', 'Jacques', 'gros'),
#  (70, 'Paulhan', 'Jean', 'gros'),
#  (72, 'Rabelais', 'Francois', 'gros'),
#  (73, 'Poe', 'Allan Edgard', 'moyen'),
#  (75, 'Ronsard', 'Pierre', 'moyen'),
#  (76, 'Racine', 'Jean', 'gros'),
#  (78, 'Sandier', 'Jules', 'moyen'),
#  (79, 'Sade', 'Donatien Alphonse Fran¿¿s de', 'gros'),
#  (81, 'Sartre', 'Jean-Paul', 'gros'),
#  (83, 'Sophocle', None, 'gros'),
#  (84, 'Sue', 'Eugene', 'moyen'),
#  (86, 'Saint Exupery', 'Antoine de', 'gros'),
#  (87, 'Segur', 'Comtesse de', 'gros'),
#  (91, 'Verlaine', 'Paul', 'gros'),
#  (93, 'Virgile', None, 'gros'),
#  (94, 'Zola', 'Emile', 'moyen'),
#  (95, 'Zorn', 'Fritz', 'moyen'),
#  (98, 'Maturin', 'Robert', 'gros'),
#  (99, 'Cesar', 'Jules', 'gros')]

# %%
# %sql SELECT * FROM RBB;
# Out:
# Done.
# [(13, 'Barthes', 'Roland', 'moyen'),
#  (16, 'Balzac', 'Honore de', 'moyen'),
#  (18, 'Celine', 'Louis Ferdinand', 'gros'),
#  (20, 'Chateaubriand', 'Francois-Rene de', 'moyen'),
#  (27, 'Dumas', 'Alexandre', 'gros'),
#  (32, 'Eluard', 'Paul', 'moyen'),
#  (35, 'Fromentin', 'Eugene', 'gros'),
#  (39, 'Montesquieu', None, 'gros'),
#  (42, 'Goethe', 'Johann Wolfgang von', 'moyen'),
#  (43, 'Musset', 'Alfred de', 'gros'),
#  (46, 'Hugo', 'Victor', 'moyen'),
#  (53, 'Lamartine', 'Alphonse de', 'gros'),
#  (55, 'Michelet', 'Jules', 'gros'),
#  (57, 'Marx', 'Karl', 'gros'),
#  (64, 'Platon', None, 'gros'),
#  (66, 'Perec', 'Georges', 'gros'),
#  (68, 'Prevert', 'Jacques', 'gros'),
#  (70, 'Paulhan', 'Jean', 'gros'),
#  (72, 'Rabelais', 'Francois', 'gros'),
#  (73, 'Poe', 'Allan Edgard', 'moyen'),
#  (76, 'Racine', 'Jean', 'gros'),
#  (78, 'Sandier', 'Jules', 'moyen'),
#  (79, 'Sade', 'Donatien Alphonse Fran¿¿s de', 'gros'),
#  (81, 'Sartre', 'Jean-Paul', 'gros'),
#  (83, 'Sophocle', None, 'gros'),
#  (84, 'Sue', 'Eugene', 'moyen'),
#  (86, 'Saint Exupery', 'Antoine de', 'gros'),
#  (87, 'Segur', 'Comtesse de', 'gros'),
#  (91, 'Verlaine', 'Paul', 'gros'),
#  (93, 'Virgile', None, 'gros'),
#  (95, 'Zorn', 'Fritz', 'moyen'),
#  (98, 'Maturin', 'Robert', 'gros'),
#  (99, 'Cesar', 'Jules', 'gros'),
#  (2, 'Artaud', 'Antonin', 'moyen'),
#  (48, 'Hardy', 'Thomas', 'moyen'),
#  (7, 'Anouilh', 'Jean', 'moyen'),
#  (8, 'Aragon', 'Louis', 'gros'),
#  (50, 'Lautreamont', None, 'moyen'),
#  (3, 'Aron', 'Raymond', 'gros'),
#  (4, 'Apollinaire', 'Guillaume', 'moyen'),
#  (58, 'Marivaux', 'Pierre Carlet de Chamblain de', 'gros'),
#  (60, 'Ovide', None, 'gros'),
#  (10, 'Andersen', 'Yann', 'gros'),
#  (6, 'Arrabal', 'Fernando', 'gros'),
#  (62, 'Proust', 'Marcel', 'moyen'),
#  (75, 'Ronsard', 'Pierre', 'moyen'),
#  (26, 'Diderot', 'Denis', 'moyen'),
#  (28, 'Dostoievsky', 'Fiodor', 'gros'),
#  (22, 'Cocteau', 'Jean', 'gros'),
#  (24, 'Courrier', 'Paul Louis', 'moyen'),
#  (12, 'Bataille', 'Georges', 'moyen'),
#  (14, 'Bory', 'Jean Louis', 'gros'),
#  (19, 'Ciceron', None, 'gros'),
#  (33, 'Flaubert', 'Gustave', 'moyen'),
#  (31, 'Dante', None, 'gros'),
#  (94, 'Zola', 'Emile', 'moyen')]

# %% [markdown]
# __2.4__ Create a table 'RBA' with the same schema as 'buveurs_asec' which contains the tuples selected from 'buveurs_asec'

# %%
# %sql DROP TABLE IF EXISTS RBA;
# %sql CREATE TABLE RBA AS SELECT * FROM buveurs_asec ORDER BY NB;
# Out:
# 4 rows affected.
# 4 rows affected.
# []

# %%
# Test
# %sql SELECT * FROM RBA
# Out:
# Done.
# [(11, 'Breton', 'Andre', 'petit'),
#  (13, 'Barthes', 'Roland', 'moyen'),
#  (16, 'Balzac', 'Honore de', 'moyen'),
#  (18, 'Celine', 'Louis Ferdinand', 'gros'),
#  (20, 'Chateaubriand', 'Francois-Rene de', 'moyen'),
#  (21, 'Corbiere', 'Tristan', 'petit'),
#  (23, 'Corneille', 'Pierre', 'petit'),
#  (25, 'Char', 'Rene', 'petit'),
#  (27, 'Dumas', 'Alexandre', 'gros'),
#  (29, 'Fournier', 'Alain', 'petit'),
#  (32, 'Eluard', 'Paul', 'moyen'),
#  (34, 'Mauriac', 'Francois', 'petit'),
#  (35, 'Fromentin', 'Eugene', 'gros'),
#  (36, 'Maurois', 'Andre', 'petit'),
#  (37, 'Freud', 'Sigmund', 'petit'),
#  (39, 'Montesquieu', None, 'gros'),
#  (42, 'Goethe', 'Johann Wolfgang von', 'moyen'),
#  (43, 'Musset', 'Alfred de', 'gros'),
#  (46, 'Hugo', 'Victor', 'moyen'),
#  (47, 'Gary', 'Romain', 'petit'),
#  (51, 'Lafargue', 'Paul', 'petit'),
#  (53, 'Lamartine', 'Alphonse de', 'gros'),
#  (54, 'Aurele', 'Marc', 'petit'),
#  (55, 'Michelet', 'Jules', 'gros'),
#  (56, 'Nerval', 'Gerard de', 'petit'),
#  (57, 'Marx', 'Karl', 'gros'),
#  (59, 'Nietzsche', 'Friedrich', 'petit'),
#  (63, 'Maupassant', 'Guy de', 'petit'),
#  (64, 'Platon', None, 'gros'),
#  (65, 'Pascal', 'Blaise', 'petit'),
#  (66, 'Perec', 'Georges', 'gros'),
#  (67, 'Nin', 'Anais', 'petit'),
#  (68, 'Prevert', 'Jacques', 'gros'),
#  (69, 'Queneau', 'Raymond', 'petit'),
#  (70, 'Paulhan', 'Jean', 'gros'),
#  (71, 'Radiguet', 'Raymond', 'petit'),
#  (72, 'Rabelais', 'Francois', 'gros'),
#  (73, 'Poe', 'Allan Edgard', 'moyen'),
#  (74, 'Rimbaud', 'Arthur', 'petit'),
#  (76, 'Racine', 'Jean', 'gros'),
#  (77, 'Rousseau', 'Jean-Jacques', 'petit'),
#  (78, 'Sandier', 'Jules', 'moyen'),
#  (79, 'Sade', 'Donatien Alphonse Fran¿¿s de', 'gros'),
#  (81, 'Sartre', 'Jean-Paul', 'gros'),
#  (83, 'Sophocle', None, 'gros'),
#  (84, 'Sue', 'Eugene', 'moyen'),
#  (85, 'Segalen', 'Victor', 'petit'),
#  (86, 'Saint Exupery', 'Antoine de', 'gros'),
#  (87, 'Segur', 'Comtesse de', 'gros'),
#  (88, 'Shakespeare', 'William', 'petit'),
#  (89, 'Stendhal', None, 'petit'),
#  (90, 'Vian', 'Boris', 'petit'),
#  (91, 'Verlaine', 'Paul', 'gros'),
#  (93, 'Virgile', None, 'gros'),
#  (95, 'Zorn', 'Fritz', 'moyen'),
#  (98, 'Maturin', 'Robert', 'gros'),
#  (99, 'Cesar', 'Jules', 'gros')]

# %% [markdown]
# __2.5__ Insert a tuple (101, 'your last name', 'your first name', 'your type of purchases(petit, moyen, or gros)') to 'RBA'

# %%
# %sql INSERT INTO RBA (NB, NOM, PRENOM, TYPE) VALUES (101, 'Callebat', 'Julia', 'petit');
# Out:
# 1 rows affected.
# []

# %%
# Test
# %sql SELECT * FROM RBA
# Out:
# Done.
# [(11, 'Breton', 'Andre', 'petit'),
#  (13, 'Barthes', 'Roland', 'moyen'),
#  (16, 'Balzac', 'Honore de', 'moyen'),
#  (18, 'Celine', 'Louis Ferdinand', 'gros'),
#  (20, 'Chateaubriand', 'Francois-Rene de', 'moyen'),
#  (21, 'Corbiere', 'Tristan', 'petit'),
#  (23, 'Corneille', 'Pierre', 'petit'),
#  (25, 'Char', 'Rene', 'petit'),
#  (27, 'Dumas', 'Alexandre', 'gros'),
#  (29, 'Fournier', 'Alain', 'petit'),
#  (32, 'Eluard', 'Paul', 'moyen'),
#  (34, 'Mauriac', 'Francois', 'petit'),
#  (35, 'Fromentin', 'Eugene', 'gros'),
#  (36, 'Maurois', 'Andre', 'petit'),
#  (37, 'Freud', 'Sigmund', 'petit'),
#  (39, 'Montesquieu', None, 'gros'),
#  (42, 'Goethe', 'Johann Wolfgang von', 'moyen'),
#  (43, 'Musset', 'Alfred de', 'gros'),
#  (46, 'Hugo', 'Victor', 'moyen'),
#  (47, 'Gary', 'Romain', 'petit'),
#  (51, 'Lafargue', 'Paul', 'petit'),
#  (53, 'Lamartine', 'Alphonse de', 'gros'),
#  (54, 'Aurele', 'Marc', 'petit'),
#  (55, 'Michelet', 'Jules', 'gros'),
#  (56, 'Nerval', 'Gerard de', 'petit'),
#  (57, 'Marx', 'Karl', 'gros'),
#  (59, 'Nietzsche', 'Friedrich', 'petit'),
#  (63, 'Maupassant', 'Guy de', 'petit'),
#  (64, 'Platon', None, 'gros'),
#  (65, 'Pascal', 'Blaise', 'petit'),
#  (66, 'Perec', 'Georges', 'gros'),
#  (67, 'Nin', 'Anais', 'petit'),
#  (68, 'Prevert', 'Jacques', 'gros'),
#  (69, 'Queneau', 'Raymond', 'petit'),
#  (70, 'Paulhan', 'Jean', 'gros'),
#  (71, 'Radiguet', 'Raymond', 'petit'),
#  (72, 'Rabelais', 'Francois', 'gros'),
#  (73, 'Poe', 'Allan Edgard', 'moyen'),
#  (74, 'Rimbaud', 'Arthur', 'petit'),
#  (76, 'Racine', 'Jean', 'gros'),
#  (77, 'Rousseau', 'Jean-Jacques', 'petit'),
#  (78, 'Sandier', 'Jules', 'moyen'),
#  (79, 'Sade', 'Donatien Alphonse Fran¿¿s de', 'gros'),
#  (81, 'Sartre', 'Jean-Paul', 'gros'),
#  (83, 'Sophocle', None, 'gros'),
#  (84, 'Sue', 'Eugene', 'moyen'),
#  (85, 'Segalen', 'Victor', 'petit'),
#  (86, 'Saint Exupery', 'Antoine de', 'gros'),
#  (87, 'Segur', 'Comtesse de', 'gros'),
#  (88, 'Shakespeare', 'William', 'petit'),
#  (89, 'Stendhal', None, 'petit'),
#  (90, 'Vian', 'Boris', 'petit'),
#  (91, 'Verlaine', 'Paul', 'gros'),
#  (93, 'Virgile', None, 'gros'),
#  (95, 'Zorn', 'Fritz', 'moyen'),
#  (98, 'Maturin', 'Robert', 'gros'),
#  (99, 'Cesar', 'Jules', 'gros'),
#  (101, 'Callebat', 'Julia', 'petit')]

# %% [markdown]
# __2.6__ Compare the content of _table_ 'RBA' and the _view_ 'buveurs_asec'. What differences do you see? Explain

# %% [raw]
# Answer: Since we modified RBA and not the tables from which it was created, the view still shows the unmodified table.

# %%
# %sql SELECT * FROM buveurs_asec;
# Out:
# Done.
# [(11, 'Breton', 'Andre', 'petit'),
#  (13, 'Barthes', 'Roland', 'moyen'),
#  (16, 'Balzac', 'Honore de', 'moyen'),
#  (18, 'Celine', 'Louis Ferdinand', 'gros'),
#  (20, 'Chateaubriand', 'Francois-Rene de', 'moyen'),
#  (21, 'Corbiere', 'Tristan', 'petit'),
#  (23, 'Corneille', 'Pierre', 'petit'),
#  (25, 'Char', 'Rene', 'petit'),
#  (27, 'Dumas', 'Alexandre', 'gros'),
#  (29, 'Fournier', 'Alain', 'petit'),
#  (32, 'Eluard', 'Paul', 'moyen'),
#  (34, 'Mauriac', 'Francois', 'petit'),
#  (35, 'Fromentin', 'Eugene', 'gros'),
#  (36, 'Maurois', 'Andre', 'petit'),
#  (37, 'Freud', 'Sigmund', 'petit'),
#  (39, 'Montesquieu', None, 'gros'),
#  (42, 'Goethe', 'Johann Wolfgang von', 'moyen'),
#  (43, 'Musset', 'Alfred de', 'gros'),
#  (46, 'Hugo', 'Victor', 'moyen'),
#  (47, 'Gary', 'Romain', 'petit'),
#  (51, 'Lafargue', 'Paul', 'petit'),
#  (53, 'Lamartine', 'Alphonse de', 'gros'),
#  (54, 'Aurele', 'Marc', 'petit'),
#  (55, 'Michelet', 'Jules', 'gros'),
#  (56, 'Nerval', 'Gerard de', 'petit'),
#  (57, 'Marx', 'Karl', 'gros'),
#  (59, 'Nietzsche', 'Friedrich', 'petit'),
#  (63, 'Maupassant', 'Guy de', 'petit'),
#  (64, 'Platon', None, 'gros'),
#  (65, 'Pascal', 'Blaise', 'petit'),
#  (66, 'Perec', 'Georges', 'gros'),
#  (67, 'Nin', 'Anais', 'petit'),
#  (68, 'Prevert', 'Jacques', 'gros'),
#  (69, 'Queneau', 'Raymond', 'petit'),
#  (70, 'Paulhan', 'Jean', 'gros'),
#  (71, 'Radiguet', 'Raymond', 'petit'),
#  (72, 'Rabelais', 'Francois', 'gros'),
#  (73, 'Poe', 'Allan Edgard', 'moyen'),
#  (74, 'Rimbaud', 'Arthur', 'petit'),
#  (76, 'Racine', 'Jean', 'gros'),
#  (77, 'Rousseau', 'Jean-Jacques', 'petit'),
#  (78, 'Sandier', 'Jules', 'moyen'),
#  (79, 'Sade', 'Donatien Alphonse Fran¿¿s de', 'gros'),
#  (81, 'Sartre', 'Jean-Paul', 'gros'),
#  (83, 'Sophocle', None, 'gros'),
#  (84, 'Sue', 'Eugene', 'moyen'),
#  (85, 'Segalen', 'Victor', 'petit'),
#  (86, 'Saint Exupery', 'Antoine de', 'gros'),
#  (87, 'Segur', 'Comtesse de', 'gros'),
#  (88, 'Shakespeare', 'William', 'petit'),
#  (89, 'Stendhal', None, 'petit'),
#  (90, 'Vian', 'Boris', 'petit'),
#  (91, 'Verlaine', 'Paul', 'gros'),
#  (93, 'Virgile', None, 'gros'),
#  (95, 'Zorn', 'Fritz', 'moyen'),
#  (98, 'Maturin', 'Robert', 'gros'),
#  (99, 'Cesar', 'Jules', 'gros')]

# %%
# %sql SELECT * FROM RBA;
# Out:
# Done.
# [(11, 'Breton', 'Andre', 'petit'),
#  (13, 'Barthes', 'Roland', 'moyen'),
#  (16, 'Balzac', 'Honore de', 'moyen'),
#  (18, 'Celine', 'Louis Ferdinand', 'gros'),
#  (20, 'Chateaubriand', 'Francois-Rene de', 'moyen'),
#  (21, 'Corbiere', 'Tristan', 'petit'),
#  (23, 'Corneille', 'Pierre', 'petit'),
#  (25, 'Char', 'Rene', 'petit'),
#  (27, 'Dumas', 'Alexandre', 'gros'),
#  (29, 'Fournier', 'Alain', 'petit'),
#  (32, 'Eluard', 'Paul', 'moyen'),
#  (34, 'Mauriac', 'Francois', 'petit'),
#  (35, 'Fromentin', 'Eugene', 'gros'),
#  (36, 'Maurois', 'Andre', 'petit'),
#  (37, 'Freud', 'Sigmund', 'petit'),
#  (39, 'Montesquieu', None, 'gros'),
#  (42, 'Goethe', 'Johann Wolfgang von', 'moyen'),
#  (43, 'Musset', 'Alfred de', 'gros'),
#  (46, 'Hugo', 'Victor', 'moyen'),
#  (47, 'Gary', 'Romain', 'petit'),
#  (51, 'Lafargue', 'Paul', 'petit'),
#  (53, 'Lamartine', 'Alphonse de', 'gros'),
#  (54, 'Aurele', 'Marc', 'petit'),
#  (55, 'Michelet', 'Jules', 'gros'),
#  (56, 'Nerval', 'Gerard de', 'petit'),
#  (57, 'Marx', 'Karl', 'gros'),
#  (59, 'Nietzsche', 'Friedrich', 'petit'),
#  (63, 'Maupassant', 'Guy de', 'petit'),
#  (64, 'Platon', None, 'gros'),
#  (65, 'Pascal', 'Blaise', 'petit'),
#  (66, 'Perec', 'Georges', 'gros'),
#  (67, 'Nin', 'Anais', 'petit'),
#  (68, 'Prevert', 'Jacques', 'gros'),
#  (69, 'Queneau', 'Raymond', 'petit'),
#  (70, 'Paulhan', 'Jean', 'gros'),
#  (71, 'Radiguet', 'Raymond', 'petit'),
#  (72, 'Rabelais', 'Francois', 'gros'),
#  (73, 'Poe', 'Allan Edgard', 'moyen'),
#  (74, 'Rimbaud', 'Arthur', 'petit'),
#  (76, 'Racine', 'Jean', 'gros'),
#  (77, 'Rousseau', 'Jean-Jacques', 'petit'),
#  (78, 'Sandier', 'Jules', 'moyen'),
#  (79, 'Sade', 'Donatien Alphonse Fran¿¿s de', 'gros'),
#  (81, 'Sartre', 'Jean-Paul', 'gros'),
#  (83, 'Sophocle', None, 'gros'),
#  (84, 'Sue', 'Eugene', 'moyen'),
#  (85, 'Segalen', 'Victor', 'petit'),
#  (86, 'Saint Exupery', 'Antoine de', 'gros'),
#  (87, 'Segur', 'Comtesse de', 'gros'),
#  (88, 'Shakespeare', 'William', 'petit'),
#  (89, 'Stendhal', None, 'petit'),
#  (90, 'Vian', 'Boris', 'petit'),
#  (91, 'Verlaine', 'Paul', 'gros'),
#  (93, 'Virgile', None, 'gros'),
#  (95, 'Zorn', 'Fritz', 'moyen'),
#  (98, 'Maturin', 'Robert', 'gros'),
#  (99, 'Cesar', 'Jules', 'gros'),
#  (101, 'Callebat', 'Julia', 'petit')]

# %% [markdown]
# ___
# # PART III: Design the database schema for posts in a Social Network
#
# In this section you need to design the database schema for a social network app of a new startup:
#
# The new social network will contain users, where each user will have a name, a nickname, an email, date of birth, and an address (Street, City, State, Country, Postal Code). Users can be friends of other users, and can publish posts. Each post can contain a text, date and attachment. Posts can be either original posts or replies so the app needs to handle both scenarios. When users log in, the app needs to display the posts of their friends.

# %% [markdown]
# __3.1__ Write and explain the design of the relations of your database

# %% [raw]
# Answer: First of all, we need to have a relation User(name, nickname, email, date of birth, address) I suppose here that the address is a string containing the street, city, state, country and postal code, since in this schema it is not usefull from what is said here to be able to compute in details the addresses. I will also suppose that all nicknames are unique (if not, it is simple to assign a user code UC to each user and to change nickname to UC in the other relations).
# We also have the relation Friends(nickname, friend_nickname), in which we can suppose that friendship is mutual to save space and computational power.
# Finally, we need the relation Post(Post_ID, text, date, attachment, type) in which the type is either 'original' or 'replies', and 'text', 'date' and 'attachment' can be NULLs.

# %% [markdown]
# __3.2__ Write a view to retrieve the posts to display when a user logs in. Consider that some users may have a lot of friends and you need to limit the number of post to display. How would you select relevant posts to display first? What kind of information would you use/add in the database for this purpose? Explain your answer.
#
# __Note:__ Limiting the number of posts just by count is too simplistic, the user could be missing something interesting to him/her.

# %% [raw]
# Answer: One solution might be to consider that relevant posts are posts from the closest friends in term of affinity. It is then necessary to add an attribute 'affinity' in the Friends relation, that could be calculated and updated according to the number of replies from that friend to the user and vice versa, all ponderated by the number of replies each one of them posted in total.
# Another solution that could be complimentary would be to decompose the address to have a simple access for exemple to the Postal Code so as to be able to filter the posts by geographical proximity.
